# %%
msg='''
魔羯座:12.22~1.19
水瓶座:1.20~2.18
雙魚座:2.19~3.20
牡羊座:3.21~4.19
金牛座:4.20~5.20
雙子座:5.21~6.20
巨蟹座:6.21~7.22
獅子座:7.23~8.22
處女座:8.23~9.22
天秤座:9.23~10.22
天蠍座:10.23~11.21
射手座:11.22~12.21
'''
out=msg.split()

birth=float(input('輸入您的生日(月.日):'))

if 1.20<=birth<=2.18:
    i=1
elif 2.19<=birth<=3.20:
    i=2
elif 3.21<=birth<=4.19:
    i=3
elif 4.20<=birth<=5.20:
    i=4
elif 5.21<=birth<=6.20:
    i=5
elif 6.21<=birth<=7.22:
    i=6
elif 7.23<=birth<=8.22:
    i=7
elif 8.23<=birth<=9.22:
    i=8
elif 9.23<=birth<=10.22:
    i=9
elif 10.23<=birth<=11.21:
    i=10
elif 11.22<=birth<=12.21:
    i=11
elif birth>12.22 or birth<=1.19:
    i=0

print(f'您是:{out[i][:3]}')
print(out[i])
# Out:
# 輸入您的生日(月.日):6.21
# 您是:巨蟹座
# 巨蟹座:6.21~7.22

# %%
namestr = "廖靜宜、吳百凱、陳懿沛、蔡仁芸、王彥君、陳鈺瑋、林珊群、許萬昌、黃靜東、陳佩舜、林怡喜"

name=namestr.split('、')
name.sort()

dic={}

for i in range(len(name)):
    if dic.get(name[i][0]):
      names=names + '，' + name[i][1:]
      dic[name[i][0]]=names
    else:
      names=name[i][1:]
    dic[name[i][0]]=names
for last_name, first_names in dic.items():
    print(f'{last_name}: {first_names}')
# Out:
# 吳: 百凱
# 廖: 靜宜
# 林: 怡喜，珊群
# 王: 彥君
# 蔡: 仁芸
# 許: 萬昌
# 陳: 佩舜，懿沛，鈺瑋
# 黃: 靜東
